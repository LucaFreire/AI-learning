# %% [markdown]
# <a href="https://colab.research.google.com/gist/LucaFreire/a1d3769ad0ae22566b69da06d15db763/ol-este-o-colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# libraries
# !pip install -U scikit-learn
# !pip install pandas
# !pip install joblib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 22.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ...

# %%
# libraries
from sklearn.datasets import load_breast_cancer
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from joblib import load, dump

# %%
# training
dataset = load_breast_cancer()
X = dataset.data
Y = dataset.target

#test_size=0.2 : 20% do dataset é para testes
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.02, random_state=800)

model = DecisionTreeClassifier()
model.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
# The accuracy
# by X_test, predict the Y
Y_pred = model.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
print(accuracy)
# Out:
# 0.9166666666666666

# %%
#Tree and Confusion Matrix
plot_tree(model)
confusion_matrix(Y_test, Y_pred)
# Out:
# array([[3, 0],
#        [1, 8]])

# %%
dump(model, "mymodel.pkl")

myModel = load("mymodel.pkl")
prediction = model.predict([[2,3,4,6,2,2,3,4,6,2,2,3,4,6,2,2,3,4,6,2,2,3,4,6,2,2,3,4,6,2]])
print(prediction)
# Out:
# [0]
